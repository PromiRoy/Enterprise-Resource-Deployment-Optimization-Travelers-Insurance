# %%
#conda install geopandas
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.7.1
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/jupyterhub/miniforge/envs/python3.12-scipy
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-2.305                 |         openblas          18 KB  conda-forge
#     blas-devel-3.11.0          |5_h1ea3ea9_openblas          18 KB  conda-forge
#     branca-0.8.2               |     pyhd8ed1ab_0          29 KB  conda-forge
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
# ...
