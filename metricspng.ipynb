# %% [markdown]
# ## ENV Setup

# %%
from PIL import Image

# %% [markdown]
# ## Downloading Metrics Picture

# %%
path = './Metrics.png'
Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2448x1148>
